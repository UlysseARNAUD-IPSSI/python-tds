# %% [markdown]
# # Ceci est un titre
#
# Ajouter texte ici

# %%
# !pip install seasonal
# !pip install pandas
# !pip install numpy
# !pip install odfpy
# Out:
# Requirement already satisfied: seasonal in c:\users\uarnaud\anaconda3\lib\site-packages (0.3.1)
# Requirement already satisfied: numpy in c:\users\uarnaud\anaconda3\lib\site-packages (from seasonal) (1.18.5)
# Requirement already satisfied: scipy in c:\users\uarnaud\anaconda3\lib\site-packages (from seasonal) (1.5.0)
# Requirement already satisfied: pandas in c:\users\uarnaud\anaconda3\lib\site-packages (1.0.5)
# Requirement already satisfied: pytz>=2017.2 in c:\users\uarnaud\anaconda3\lib\site-packages (from pandas) (2020.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\uarnaud\anaconda3\lib\site-packages (from pandas) (1.18.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\uarnaud\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\uarnaud\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas) (1.15.0)
# Requirement already satisfied: numpy in c:\users\uarnaud\anaconda3\lib\site-packages (1.18.5)
# Collecting odfpy
#   Downloading odfpy-1.4.1.tar.gz (717 kB)
# Requirement already satisfied: defusedxml in c:\users\uarnaud\anaconda3\lib\site-packages (from odfpy) (0.6.0)
# Building wheels for collected packages: odfpy
#   Building wheel for odfpy (setup.py): started
#   Building wheel for odfpy (setup.py): finished with status 'done'
#   Created wheel for odfpy: filename=odfpy-1.4.1-py2.py3-none-any.whl size=137345 sha256=843af919547216faae5a22a1e327252429e50d59174f24c1223946dd3e9020cd
#   Stored in directory: c:\users\uarnaud\appdata\local\pip\cache\wheels\ea\af\da\2bdd7308f7b334429a558df1e36d31864cd19c07ede92ddf0e
# Successfully built odfpy
# Installing collected packages: odfpy
# Successfully installed odfpy-1.4.1

# %%
from statsmodels.tsa.tsatools import detrend
from statsmodels.tsa.seasonal import seasonal_decompose
from seasonal import fit_seasons

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataframe = pd.read_excel("hadopi-2020-musique-data.ods", engine="odf")
dataframe.head(1)
# Out:
#            SEXE  QSEXE        RAGE2         RAGE3              XRAGE  \
# 0     Une femme  FEMME    De65aPlus   PlusDe49ans   Femme35ansEtPlus
# 1     Une femme  FEMME  De50a64ans1   PlusDe49ans   Femme35ansEtPlus
# 2     Une femme  FEMME   De15a24ans  MoinsDe35ans  FemmeMoinsDe35ans
# 3     Une femme  FEMME  De35a49ans1   De35a49ans2   Femme35ansEtPlus
# 4      Un homme  HOMME  De50a64ans1   PlusDe49ans   Homme35ansEtPlus
# ...         ...    ...          ...           ...                ...
# 2195  Une femme  FEMME  De35a49ans1   De35a49ans2   Femme35ansEtPlus
# 2196   Un homme  HOMME  De35a49ans1   De35a49ans2   Homme35ansEtPlus
# 2197  Une femme  FEMME  De35a49ans1   De35a49ans2   Femme35ansEtPlus
# 2198  Une femme  FEMME  De35a49ans1   De35a49ans2   Femme35ansEtPlus
# 2199  Une femme  FEMME  De35a49ans1   De35a49ans2   Femme35ansEtPlus
#
#                   AGGLOIFOP2   REG   REG2      REG3                     REG13  \
# 0     MoinsDe100000Habitants  UDA7  BUDA4  PROVINCE  LanguedicRoussillonMidiP
# 1      PlusDe100000Habitants  UDA6  BUDA3  PROVINCE            PaysDeLaLoire1
# 2      PlusDe100000Habitants  UDA2  BUDA2  PROVINCE   NordPasDeCalaisPicardie
# 3      PlusDe100000Habitants  UDA9  BUDA5  PROVINCE    ProvenceAlpesCoteDAzur
# 4     MoinsDe100000Habitants  UDA8  BUDA5  PROVINCE        AuvergneRhoneAlpes
# ...                      ...   ...    ...       ...                       ...
# 2195  MoinsDe100000Habitants  UDA5  BUDA3  PROVINCE                 Normandie
# 2196  MoinsDe100000Habitants  UDA8  BUDA5  PROVINCE        AuvergneRhoneAlpes
# 2197  MoinsDe100000Habitants  UDA5  BUDA3  PROVINCE                 Normandie
# 2198  MoinsDe100000Habitants  UDA6  BUDA3  PROVINCE            PaysDeLaLoire1
# 2199  MoinsDe100000Habitants  UDA9  BUDA5  PROVINCE  LanguedicRoussillonMidiP
#
#       ...                                        Q60_3  \
# 0     ...                                        #NUL!
# 1     ...                                            0
# 2     ...  L’offre légale est plus agréable à utiliser
# 3     ...                                        #NUL!
# 4     ...                                            0
# ...   ...                                          ...
# 2195  ...                                        #NUL!
# 2196  ...                                        #NUL!
# 2197  ...                                        #NUL!
# 2198  ...                                        #NUL!
# 2199  ...                                            0
#
#                                           Q60_4  Q60_5       Q61_r1_c1  \
# 0                                         #NUL!  #NUL!           #NUL!
# 1                                             0      0     150 et plus
# 2                                             0      0  Entre 50 et 99
# 3                                         #NUL!  #NUL!     Moins de 50
# 4                                             0      0     Moins de 50
# ...                                         ...    ...             ...
# 2195                                      #NUL!  #NUL!     Moins de 50
# 2196                                      #NUL!  #NUL!     150 et plus
# 2197                                      #NUL!  #NUL!           #NUL!
# 2198                                      #NUL!  #NUL!           #NUL!
# 2199  L’offre légale gratuite est satisfaisante      0  Entre 50 et 99
#
#           Q61_r2_c1       Q61_r3_c1    Q61_r4_c1 DISPQUAL sys_block_set_1  \
# 0     Entre 1 et 49           #NUL!        #NUL!     Long           2,3,1
# 1        50 et plus           #NUL!        #NUL!     Long           3,2,1
# 2             #NUL!  Entre 50 et 99        #NUL!     Long           1,3,2
# 3     Entre 1 et 49           #NUL!        #NUL!     Long           1,2,3
# 4                 0           #NUL!  Moins de 20     Long           2,1,3
# ...             ...             ...          ...      ...             ...
# 2195  Entre 1 et 49           #NUL!        #NUL!     Long           1,2,3
# 2196     50 et plus           #NUL!        #NUL!     Long           2,3,1
# 2197          #NUL!           #NUL!        #NUL!    Court             NaN
# 2198          #NUL!           #NUL!        #NUL!    Court             NaN
# 2199          #NUL!           #NUL!        #NUL!     Long           2,3,1
#
#          poids
# 0     1.006791
# 1     0.695394
# 2     0.659261
# 3     1.165641
# 4     1.819044
# ...        ...
# 2195  2.557586
# 2196  2.567871
# 2197  2.557586
# 2198  2.560643
# 2199  2.654793
#
# [2200 rows x 261 columns]

# %%
dataframe = dataframe.replace('LanguedicRoussillon', 'LanguedocRoussillon', regex=True)
dataframe = dataframe.replace('#NUL!', NaN, regex=True)
dataframe
# Out:
#            SEXE  QSEXE        RAGE2         RAGE3              XRAGE  \
# 0     Une femme  FEMME    De65aPlus   PlusDe49ans   Femme35ansEtPlus
# 1     Une femme  FEMME  De50a64ans1   PlusDe49ans   Femme35ansEtPlus
# 2     Une femme  FEMME   De15a24ans  MoinsDe35ans  FemmeMoinsDe35ans
# 3     Une femme  FEMME  De35a49ans1   De35a49ans2   Femme35ansEtPlus
# 4      Un homme  HOMME  De50a64ans1   PlusDe49ans   Homme35ansEtPlus
# ...         ...    ...          ...           ...                ...
# 2195  Une femme  FEMME  De35a49ans1   De35a49ans2   Femme35ansEtPlus
# 2196   Un homme  HOMME  De35a49ans1   De35a49ans2   Homme35ansEtPlus
# 2197  Une femme  FEMME  De35a49ans1   De35a49ans2   Femme35ansEtPlus
# 2198  Une femme  FEMME  De35a49ans1   De35a49ans2   Femme35ansEtPlus
# 2199  Une femme  FEMME  De35a49ans1   De35a49ans2   Femme35ansEtPlus
#
#                   AGGLOIFOP2   REG   REG2      REG3                     REG13  \
# 0     MoinsDe100000Habitants  UDA7  BUDA4  PROVINCE  LanguedocRoussillonMidiP
# 1      PlusDe100000Habitants  UDA6  BUDA3  PROVINCE            PaysDeLaLoire1
# 2      PlusDe100000Habitants  UDA2  BUDA2  PROVINCE   NordPasDeCalaisPicardie
# 3      PlusDe100000Habitants  UDA9  BUDA5  PROVINCE    ProvenceAlpesCoteDAzur
# 4     MoinsDe100000Habitants  UDA8  BUDA5  PROVINCE        AuvergneRhoneAlpes
# ...                      ...   ...    ...       ...                       ...
# 2195  MoinsDe100000Habitants  UDA5  BUDA3  PROVINCE                 Normandie
# 2196  MoinsDe100000Habitants  UDA8  BUDA5  PROVINCE        AuvergneRhoneAlpes
# 2197  MoinsDe100000Habitants  UDA5  BUDA3  PROVINCE                 Normandie
# 2198  MoinsDe100000Habitants  UDA6  BUDA3  PROVINCE            PaysDeLaLoire1
# 2199  MoinsDe100000Habitants  UDA9  BUDA5  PROVINCE  LanguedocRoussillonMidiP
#
#       ...                                        Q60_3  \
# 0     ...                                        #NUL!
# 1     ...                                            0
# 2     ...  L’offre légale est plus agréable à utiliser
# 3     ...                                        #NUL!
# 4     ...                                            0
# ...   ...                                          ...
# 2195  ...                                        #NUL!
# 2196  ...                                        #NUL!
# 2197  ...                                        #NUL!
# 2198  ...                                        #NUL!
# 2199  ...                                            0
#
#                                           Q60_4  Q60_5       Q61_r1_c1  \
# 0                                         #NUL!  #NUL!           #NUL!
# 1                                             0      0     150 et plus
# 2                                             0      0  Entre 50 et 99
# 3                                         #NUL!  #NUL!     Moins de 50
# 4                                             0      0     Moins de 50
# ...                                         ...    ...             ...
# 2195                                      #NUL!  #NUL!     Moins de 50
# 2196                                      #NUL!  #NUL!     150 et plus
# 2197                                      #NUL!  #NUL!           #NUL!
# 2198                                      #NUL!  #NUL!           #NUL!
# 2199  L’offre légale gratuite est satisfaisante      0  Entre 50 et 99
#
#           Q61_r2_c1       Q61_r3_c1    Q61_r4_c1 DISPQUAL sys_block_set_1  \
# 0     Entre 1 et 49           #NUL!        #NUL!     Long           2,3,1
# 1        50 et plus           #NUL!        #NUL!     Long           3,2,1
# 2             #NUL!  Entre 50 et 99        #NUL!     Long           1,3,2
# 3     Entre 1 et 49           #NUL!        #NUL!     Long           1,2,3
# 4                 0           #NUL!  Moins de 20     Long           2,1,3
# ...             ...             ...          ...      ...             ...
# 2195  Entre 1 et 49           #NUL!        #NUL!     Long           1,2,3
# 2196     50 et plus           #NUL!        #NUL!     Long           2,3,1
# 2197          #NUL!           #NUL!        #NUL!    Court             NaN
# 2198          #NUL!           #NUL!        #NUL!    Court             NaN
# 2199          #NUL!           #NUL!        #NUL!     Long           2,3,1
#
#          poids
# 0     1.006791
# 1     0.695394
# 2     0.659261
# 3     1.165641
# 4     1.819044
# ...        ...
# 2195  2.557586
# 2196  2.567871
# 2197  2.557586
# 2198  2.560643
# 2199  2.654793
#
# [2200 rows x 261 columns]

# %%
dataframe = dataframe.dropna(axis = 'columns', how = 'all')
dataframe.head(1)
# Out:
#         SEXE  QSEXE      RAGE2        RAGE3             XRAGE  \
# 0  Une femme  FEMME  De65aPlus  PlusDe49ans  Femme35ansEtPlus
#
#                AGGLOIFOP2   REG   REG2      REG3                     REG13  \
# 0  MoinsDe100000Habitants  UDA7  BUDA4  PROVINCE  LanguedicRoussillonMidiP
#
#    ...  Q60_3  Q60_4  Q60_5 Q61_r1_c1      Q61_r2_c1 Q61_r3_c1 Q61_r4_c1  \
# 0  ...  #NUL!  #NUL!  #NUL!     #NUL!  Entre 1 et 49     #NUL!     #NUL!
#
#   DISPQUAL sys_block_set_1     poids
# 0     Long           2,3,1  1.006791
#
# [1 rows x 261 columns]

# %%
dataframe.groupby('SEXE').size().to_dict()
# Out:
# {'FEMME': 1127, 'HOMME': 1073}

# %%
dataframe.groupby('QSEXE').size().to_dict()
# Out:
# {'FEMME': 1127, 'HOMME': 1073}
